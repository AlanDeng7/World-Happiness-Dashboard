# %%
import pandas as pd
import numpy as np
pd.options.display.max_colwidth = 200

import json

# %%
# Load world happiness data 2015 
WHI_2015_df = pd.read_csv("../Raw Data/World Happiness Index/2015.csv")
WHI_2015_df = WHI_2015_df[["Country", "Happiness Rank","Happiness Score",
                "Economy (GDP per Capita)","Family","Health (Life Expectancy)",
                "Freedom","Trust (Government Corruption)","Generosity"]]

WHI_2015_df.rename(columns={"Economy (GDP per Capita)":"GDP",
            "Health (Life Expectancy)":"Life Expectancy",
            "Trust (Government Corruption)":"Corruption"}, inplace=True)
            
WHI_2015_df
# Out:
#          Country  Happiness Rank  Happiness Score      GDP   Family  \
# 0    Switzerland               1            7.587  1.39651  1.34951
# 1        Iceland               2            7.561  1.30232  1.40223
# 2        Denmark               3            7.527  1.32548  1.36058
# 3         Norway               4            7.522  1.45900  1.33095
# 4         Canada               5            7.427  1.32629  1.32261
# ..           ...             ...              ...      ...      ...
# 153       Rwanda             154            3.465  0.22208  0.77370
# 154        Benin             155            3.340  0.28665  0.35386
# 155        Syria             156            3.006  0.66320  0.47489
# 156      Burundi             157            2.905  0.01530  0.41587
# 157         Togo             158            2.839  0.20868  0.13995
#
#      Life Expectancy  Freedom  Corruption  Generosity
# 0            0.94143  0.66557     0.41978     0.29678
# ...

# %%
# Load world happiness data 2016 
WHI_2016_df = pd.read_csv("../Raw Data/World Happiness Index/2016.csv")
WHI_2016_df = WHI_2016_df[["Country", "Happiness Rank","Happiness Score",
                "Economy (GDP per Capita)","Family","Health (Life Expectancy)",
                "Freedom","Trust (Government Corruption)","Generosity"]]

WHI_2016_df.rename(columns={"Economy (GDP per Capita)":"GDP",
            "Health (Life Expectancy)":"Life Expectancy",
            "Trust (Government Corruption)":"Corruption"}, inplace=True)

WHI_2016_df
# Out:
#          Country  Happiness Rank  Happiness Score      GDP   Family  \
# 0        Denmark               1            7.526  1.44178  1.16374
# 1    Switzerland               2            7.509  1.52733  1.14524
# 2        Iceland               3            7.501  1.42666  1.18326
# 3         Norway               4            7.498  1.57744  1.12690
# 4        Finland               5            7.413  1.40598  1.13464
# ..           ...             ...              ...      ...      ...
# 152        Benin             153            3.484  0.39499  0.10419
# 153  Afghanistan             154            3.360  0.38227  0.11037
# 154         Togo             155            3.303  0.28123  0.00000
# 155        Syria             156            3.069  0.74719  0.14866
# 156      Burundi             157            2.905  0.06831  0.23442
#
#      Life Expectancy  Freedom  Corruption  Generosity
# 0            0.79504  0.57941     0.44453     0.36171
# ...

# %%
# Load world happiness data 2017 
WHI_2017_df = pd.read_csv("../Raw Data/World Happiness Index/2017.csv")
WHI_2017_df = WHI_2017_df[["Country", "Happiness.Rank","Happiness.Score",
                "Economy..GDP.per.Capita.","Family","Health..Life.Expectancy.",
                "Freedom","Trust..Government.Corruption.","Generosity"]]

WHI_2017_df.rename(columns={"Happiness.Rank":"Happiness Rank",
                "Happiness.Score":"Happiness Score",
                "Economy..GDP.per.Capita.":"GDP",
                "Health..Life.Expectancy.":"Life Expectancy",
                "Trust..Government.Corruption.":"Corruption"}, inplace=True)
                
WHI_2017_df
# Out:
#                       Country  Happiness Rank  Happiness Score       GDP  \
# 0                      Norway               1            7.537  1.616463
# 1                     Denmark               2            7.522  1.482383
# 2                     Iceland               3            7.504  1.480633
# 3                 Switzerland               4            7.494  1.564980
# 4                     Finland               5            7.469  1.443572
# ..                        ...             ...              ...       ...
# 150                    Rwanda             151            3.471  0.368746
# 151                     Syria             152            3.462  0.777153
# 152                  Tanzania             153            3.349  0.511136
# 153                   Burundi             154            2.905  0.091623
# 154  Central African Republic             155            2.693  0.000000
#
#        Family  Life Expectancy   Freedom  Corruption  Generosity
# ...

# %%
# Load world happiness data 2018 
WHI_2018_df = pd.read_csv("../Raw Data/World Happiness Index/2018.csv")
WHI_2018_df = WHI_2018_df[["Country or region", "Overall rank","Score",
                "GDP per capita","Social support","Healthy life expectancy",
                "Freedom to make life choices","Perceptions of corruption","Generosity"]]

WHI_2018_df.rename(columns={"Country or region":"Country",
                "Overall rank":"Happiness Rank",
                "Score":"Happiness Score",
                "GDP per capita":"GDP",
                "Social support":"Family",
                "Healthy life expectancy":"Life Expectancy",
                "Freedom to make life choices":"Freedom",
                "Perceptions of corruption":"Corruption"}, inplace=True)

WHI_2018_df
# Out:
#                       Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0                     Finland               1            7.632  1.305   1.592
# 1                      Norway               2            7.594  1.456   1.582
# 2                     Denmark               3            7.555  1.351   1.590
# 3                     Iceland               4            7.495  1.343   1.644
# 4                 Switzerland               5            7.487  1.420   1.549
# ..                        ...             ...              ...    ...     ...
# 151                     Yemen             152            3.355  0.442   1.073
# 152                  Tanzania             153            3.303  0.455   0.991
# 153               South Sudan             154            3.254  0.337   0.608
# 154  Central African Republic             155            3.083  0.024   0.000
# 155                   Burundi             156            2.905  0.091   0.627
#
# ...

# %%
# Load world happiness data 2019 
WHI_2019_df = pd.read_csv("../Raw Data/World Happiness Index/2019.csv")
WHI_2019_df = WHI_2019_df[["Country or region", "Overall rank","Score",
                "GDP per capita","Social support","Healthy life expectancy",
                "Freedom to make life choices","Perceptions of corruption","Generosity"]]

WHI_2019_df.rename(columns={"Country or region":"Country",
                "Overall rank":"Happiness Rank",
                "Score":"Happiness Score",
                "GDP per capita":"GDP",
                "Social support":"Family",
                "Healthy life expectancy":"Life Expectancy",
                "Freedom to make life choices":"Freedom",
                "Perceptions of corruption":"Corruption"}, inplace=True)

WHI_2019_df
# Out:
#                       Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0                     Finland               1            7.769  1.340   1.587
# 1                     Denmark               2            7.600  1.383   1.573
# 2                      Norway               3            7.554  1.488   1.582
# 3                     Iceland               4            7.494  1.380   1.624
# 4                 Netherlands               5            7.488  1.396   1.522
# ..                        ...             ...              ...    ...     ...
# 151                    Rwanda             152            3.334  0.359   0.711
# 152                  Tanzania             153            3.231  0.476   0.885
# 153               Afghanistan             154            3.203  0.350   0.517
# 154  Central African Republic             155            3.083  0.026   0.000
# 155               South Sudan             156            2.853  0.306   0.575
#
# ...

# %%
# Load world happiness data 2020 
WHI_2020_df = pd.read_csv("../Raw Data/World Happiness Index/2020.csv")

WHI_2020_df["Happiness Rank"] = np.arange(len(WHI_2020_df)) + 1

WHI_2020_df = WHI_2020_df[["Country name","Happiness Rank","Ladder score",
                "Explained by: Log GDP per capita","Explained by: Social support","Explained by: Healthy life expectancy",
                "Explained by: Freedom to make life choices","Explained by: Perceptions of corruption","Explained by: Generosity"]]

WHI_2020_df.rename(columns={"Country name":"Country",
                "Overall rank":"Happiness Rank",
                "Ladder score":"Happiness Score",
                "Explained by: Log GDP per capita":"GDP",
                "Explained by: Social support":"Family",
                "Explained by: Healthy life expectancy":"Life Expectancy",
                "Explained by: Freedom to make life choices":"Freedom",
                "Explained by: Perceptions of corruption":"Corruption",
                "Explained by: Generosity":"Generosity"}, inplace=True)

WHI_2020_df
# Out:
#                       Country  Happiness Rank  Happiness Score       GDP  \
# 0                     Finland               1           7.8087  1.285190
# 1                     Denmark               2           7.6456  1.326949
# 2                 Switzerland               3           7.5599  1.390774
# 3                     Iceland               4           7.5045  1.326502
# 4                      Norway               5           7.4880  1.424207
# ..                        ...             ...              ...       ...
# 148  Central African Republic             149           3.4759  0.041072
# 149                    Rwanda             150           3.3123  0.343243
# 150                  Zimbabwe             151           3.2992  0.425564
# 151               South Sudan             152           2.8166  0.289083
# 152               Afghanistan             153           2.5669  0.300706
#
#        Family  Life Expectancy   Freedom  Corruption  Generosity
# ...

# %%
# Load world happiness data 2021
WHI_2021_df = pd.read_csv("../Raw Data/World Happiness Index/2021.csv")

WHI_2021_df["Happiness Rank"] = np.arange(len(WHI_2021_df)) + 1

WHI_2021_df = WHI_2021_df[["Country name","Happiness Rank","Ladder score",
                "Explained by: Log GDP per capita","Explained by: Social support","Explained by: Healthy life expectancy",
                "Explained by: Freedom to make life choices","Explained by: Perceptions of corruption","Explained by: Generosity"]]

WHI_2021_df.rename(columns={"Country name":"Country",
                "Overall rank":"Happiness Rank",
                "Ladder score":"Happiness Score",
                "Explained by: Log GDP per capita":"GDP",
                "Explained by: Social support":"Family",
                "Explained by: Healthy life expectancy":"Life Expectancy",
                "Explained by: Freedom to make life choices":"Freedom",
                "Explained by: Perceptions of corruption":"Corruption",
                "Explained by: Generosity":"Generosity"}, inplace=True)

WHI_2021_df
# Out:
#          Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0        Finland               1            7.842  1.446   1.106
# 1        Denmark               2            7.620  1.502   1.108
# 2    Switzerland               3            7.571  1.566   1.079
# 3        Iceland               4            7.554  1.482   1.172
# 4    Netherlands               5            7.464  1.501   1.079
# ..           ...             ...              ...    ...     ...
# 144      Lesotho             145            3.512  0.451   0.731
# 145     Botswana             146            3.467  1.099   0.724
# 146       Rwanda             147            3.415  0.364   0.202
# 147     Zimbabwe             148            3.145  0.457   0.649
# 148  Afghanistan             149            2.523  0.370   0.000
#
#      Life Expectancy  Freedom  Corruption  Generosity
# 0              0.741    0.691       0.481       0.124
# 1              0.763    0.686       0.485       0.208
# ...

# %%
# load education data
ed_df = pd.read_csv("../govt_exp_on_ed_2015_2020.csv")
ed_df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2015
# 1  Afghanistan  AFG  2016
# 2  Afghanistan  AFG  2017
# 3  Afghanistan  AFG  2018
# 4  Afghanistan  AFG  2019
#
#    Government expenditure on education, total (% of GDP)
# 0                                                3.25580
# 1                                                3.51198
# 2                                                3.37331
# 3                                                3.19979
# 4                                                3.21378

# %%
#filter only 2015 education data
ed_2015_df = ed_df.loc[ed_df["Year"] == 2015].copy()

ed_2015_df = ed_2015_df[["Entity","Government expenditure on education, total (% of GDP)"]]

ed_2015_df.rename(columns={"Entity":"Country",
                "Government expenditure on education, total (% of GDP)":"Education Expenditure"}, inplace=True)

ed_2015_df.head()
# Out:
#         Country  Education Expenditure
# 0   Afghanistan                3.25580
# 5       Albania                3.43797
# 13      Andorra                3.28035
# 18       Angola                3.48690
# 28    Argentina                5.77611

# %%
#filter only 2016 education data
ed_2016_df = ed_df.loc[ed_df["Year"] == 2016].copy()

ed_2016_df = ed_2016_df[["Entity","Government expenditure on education, total (% of GDP)"]]

ed_2016_df.rename(columns={"Entity":"Country",
                "Government expenditure on education, total (% of GDP)":"Education Expenditure"}, inplace=True)

ed_2016_df.head()
# Out:
#         Country  Education Expenditure
# 1   Afghanistan                3.51198
# 6       Albania                3.96209
# 9       Algeria                7.34436
# 14      Andorra                3.23707
# 19       Angola                2.75494

# %%
#filter only 2017 education data
ed_2017_df = ed_df.loc[ed_df["Year"] == 2017].copy()

ed_2017_df = ed_2017_df[["Entity","Government expenditure on education, total (% of GDP)"]]

ed_2017_df.rename(columns={"Entity":"Country",
                "Government expenditure on education, total (% of GDP)":"Education Expenditure"}, inplace=True)

ed_2017_df.head()
# Out:
#         Country  Education Expenditure
# 2   Afghanistan                3.37331
# 7       Albania                3.61172
# 10      Algeria                6.50538
# 15      Andorra                3.21709
# 20       Angola                2.46688

# %%
#filter only 2018 education data
ed_2018_df = ed_df.loc[ed_df["Year"] == 2018].copy()

ed_2018_df = ed_2018_df[["Entity","Government expenditure on education, total (% of GDP)"]]

ed_2018_df.rename(columns={"Entity":"Country",
                "Government expenditure on education, total (% of GDP)":"Education Expenditure"}, inplace=True)

ed_2018_df.head()
# Out:
#                 Country  Education Expenditure
# 3           Afghanistan                3.19979
# 11              Algeria                5.86635
# 16              Andorra                3.24672
# 21               Angola                2.04470
# 25  Antigua and Barbuda                2.64408

# %%
#filter only 2019 education data
ed_2019_df = ed_df.loc[ed_df["Year"] == 2019].copy()

ed_2019_df = ed_2019_df[["Entity","Government expenditure on education, total (% of GDP)"]]

ed_2019_df.rename(columns={"Entity":"Country",
                "Government expenditure on education, total (% of GDP)":"Education Expenditure"}, inplace=True)

ed_2019_df.head()
# Out:
#         Country  Education Expenditure
# 4   Afghanistan                3.21378
# 8       Albania                3.94576
# 12      Algeria                6.10036
# 17      Andorra                3.15061
# 22       Angola                1.82118

# %%
#filter only 2020 education data
ed_2020_df = ed_df.loc[ed_df["Year"] == 2020].copy()

ed_2020_df = ed_2020_df[["Entity","Government expenditure on education, total (% of GDP)"]]

ed_2020_df.rename(columns={"Entity":"Country",
                "Government expenditure on education, total (% of GDP)":"Education Expenditure"}, inplace=True)

ed_2020_df.head()
# Out:
#                 Country  Education Expenditure
# 27  Antigua and Barbuda                3.32162
# 38              Armenia                2.70476
# 59              Bahamas                2.51088
# 69             Barbados                4.29516
# 75              Belarus                4.95245

# %%
#merge 2015 happiness data with education data
WHI_ed_2015_df = WHI_2015_df.merge(ed_2015_df, on="Country", how="left")

#WHI_ed_2015_df = WHI_ed_2015_df.fillna("null")
WHI_ed_2015_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score      GDP   Family  \
# 0  Switzerland               1            7.587  1.39651  1.34951
# 1      Iceland               2            7.561  1.30232  1.40223
# 2      Denmark               3            7.527  1.32548  1.36058
# 3       Norway               4            7.522  1.45900  1.33095
# 4       Canada               5            7.427  1.32629  1.32261
#
#    Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure
# 0          0.94143  0.66557     0.41978     0.29678                4.93845
# 1          0.94784  0.62877     0.14145     0.43630                7.45797
# 2          0.87464  0.64938     0.48357     0.34139                    NaN
# 3          0.88521  0.66973     0.36503     0.34699                7.56933
# 4          0.90563  0.63297     0.32957     0.45811                    NaN

# %%
#merge 2016 happiness data with education data
WHI_ed_2016_df = WHI_2016_df.merge(ed_2016_df, on="Country", how="left")

#WHI_ed_2016_df = WHI_ed_2016_df.fillna("null")
WHI_ed_2016_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score      GDP   Family  \
# 0      Denmark               1            7.526  1.44178  1.16374
# 1  Switzerland               2            7.509  1.52733  1.14524
# 2      Iceland               3            7.501  1.42666  1.18326
# 3       Norway               4            7.498  1.57744  1.12690
# 4      Finland               5            7.413  1.40598  1.13464
#
#    Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure
# 0          0.79504  0.57941     0.44453     0.36171                    NaN
# 1          0.86303  0.58557     0.41203     0.28083                4.92646
# 2          0.86733  0.56624     0.14975     0.47678                7.43220
# 3          0.79579  0.59609     0.35776     0.37895                8.03055
# 4          0.81091  0.57104     0.41004     0.25492                6.85153

# %%
#merge 2017 happiness data with education data
WHI_ed_2017_df = WHI_2017_df.merge(ed_2017_df, on="Country", how="left")

#WHI_ed_2017_df = WHI_ed_2017_df.fillna("null")
WHI_ed_2017_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score       GDP    Family  \
# 0       Norway               1            7.537  1.616463  1.533524
# 1      Denmark               2            7.522  1.482383  1.551122
# 2      Iceland               3            7.504  1.480633  1.610574
# 3  Switzerland               4            7.494  1.564980  1.516912
# 4      Finland               5            7.469  1.443572  1.540247
#
#    Life Expectancy   Freedom  Corruption  Generosity  Education Expenditure
# 0         0.796667  0.635423    0.315964    0.362012                7.91198
# 1         0.792566  0.626007    0.400770    0.355280                7.75244
# 2         0.833552  0.627163    0.153527    0.475540                7.58386
# 3         0.858131  0.620071    0.367007    0.290549                4.95157
# 4         0.809158  0.617951    0.382612    0.245483                6.36311

# %%
#merge 2018 happiness data with education data
WHI_ed_2018_df = WHI_2018_df.merge(ed_2018_df, on="Country", how="left")

#WHI_ed_2018_df = WHI_ed_2018_df.fillna("null")
WHI_ed_2018_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0      Finland               1            7.632  1.305   1.592
# 1       Norway               2            7.594  1.456   1.582
# 2      Denmark               3            7.555  1.351   1.590
# 3      Iceland               4            7.495  1.343   1.644
# 4  Switzerland               5            7.487  1.420   1.549
#
#    Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure
# 0            0.874    0.681       0.393       0.202                6.26930
# 1            0.861    0.686       0.340       0.286                7.64411
# 2            0.868    0.683       0.408       0.284                    NaN
# 3            0.914    0.677       0.138       0.353                7.57406
# 4            0.927    0.660       0.357       0.256                4.86094

# %%
#merge 2019 happiness data with education data
WHI_ed_2019_df = WHI_2019_df.merge(ed_2019_df, on="Country", how="left")

#WHI_ed_2019_df = WHI_ed_2019_df.fillna("null")
WHI_ed_2019_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0      Finland               1            7.769  1.340   1.587
# 1      Denmark               2            7.600  1.383   1.573
# 2       Norway               3            7.554  1.488   1.582
# 3      Iceland               4            7.494  1.380   1.624
# 4  Netherlands               5            7.488  1.396   1.522
#
#    Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure
# 0            0.986    0.596       0.393       0.153                    NaN
# 1            0.996    0.592       0.410       0.252                    NaN
# 2            1.028    0.603       0.341       0.271                    NaN
# 3            1.026    0.591       0.118       0.354                    NaN
# 4            0.999    0.557       0.298       0.322                    NaN

# %%
#merge 2020 happiness data with education data
WHI_ed_2020_df = WHI_2020_df.merge(ed_2020_df, on="Country", how="left")

#WHI_ed_2020_df = WHI_ed_2020_df.fillna("null")
WHI_ed_2020_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score       GDP    Family  \
# 0      Finland               1           7.8087  1.285190  1.499526
# 1      Denmark               2           7.6456  1.326949  1.503449
# 2  Switzerland               3           7.5599  1.390774  1.472403
# 3      Iceland               4           7.5045  1.326502  1.547567
# 4       Norway               5           7.4880  1.424207  1.495173
#
#    Life Expectancy   Freedom  Corruption  Generosity  Education Expenditure
# 0         0.961271  0.662317    0.477857    0.159670                    NaN
# 1         0.979333  0.665040    0.495260    0.242793                    NaN
# 2         1.040533  0.628954    0.407946    0.269056                    NaN
# 3         1.000843  0.661981    0.144541    0.362330                    NaN
# 4         1.008072  0.670201    0.434101    0.287985                    NaN

# %%
# adding education expenditure column to 2021 data
WHI_ed_2021_df = WHI_2021_df.copy()
WHI_ed_2021_df["Education Expenditure"] = "NaN"

WHI_ed_2021_df["Education Expenditure"].astype(float)

WHI_ed_2021_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0      Finland               1            7.842  1.446   1.106
# 1      Denmark               2            7.620  1.502   1.108
# 2  Switzerland               3            7.571  1.566   1.079
# 3      Iceland               4            7.554  1.482   1.172
# 4  Netherlands               5            7.464  1.501   1.079
#
#    Life Expectancy  Freedom  Corruption  Generosity Education Expenditure
# 0            0.741    0.691       0.481       0.124                   NaN
# 1            0.763    0.686       0.485       0.208                   NaN
# 2            0.816    0.653       0.413       0.204                   NaN
# 3            0.772    0.698       0.170       0.293                   NaN
# 4            0.753    0.647       0.384       0.302                   NaN

# %%
# Load world population data
population_df = pd.read_csv("../Raw Data/population-and-demography.csv")
population_df.head()
# Out:
#   Country name  Year  65+ years  25-64 years  15-24 years  5-14 years  \
# 0  Afghanistan  1950     213022      2773093      1425494     1820573
# 1  Afghanistan  1951     216096      2803308      1446694     1858587
# 2  Afghanistan  1952     219028      2834902      1468534     1896850
# 3  Afghanistan  1953     221925      2866392      1489850     1931657
# 4  Afghanistan  1954     224755      2898163      1510311     1963243
#
#    Under-5s
# 0   1248282
# 1   1246857
# 2   1248220
# 3   1254725
# 4   1267817

# %%
# Load 2015 world population data
pop_2015_df = population_df.loc[population_df["Year"] == 2015].copy()

pop_2015_df = pop_2015_df[["Country name","65+ years","25-64 years","15-24 years","5-14 years","Under-5s"]]

pop_2015_df.rename(columns={"Country name":"Country",
                "65+ years":"Age 65+",
                "25-64 years":"Age 64-25",
                "15-24 years":"Age 24-15",
                "5-14 years":"Age 14-5",
                "Under-5s":"Age <5",}, inplace=True)

pop_2015_df["Total Population"] = pop_2015_df["Age 65+"] + pop_2015_df["Age 64-25"] + pop_2015_df["Age 24-15"] + pop_2015_df["Age 14-5"] + pop_2015_df["Age <5"]

pop_2015_df.head()
# Out:
#             Country   Age 65+  Age 64-25  Age 24-15   Age 14-5     Age <5  \
# 65      Afghanistan    812050   10233436    7251576    9708575    5747862
# 137     Africa (UN)  39619096  435075400  230922500  306197950  189293000
# 209         Albania    390100    1473157     495573     356034     167618
# 281         Algeria   2052587   19560708    6461066    6845362    4623426
# 353  American Samoa      2550      22753       9905      10801       5382
#
#      Total Population
# 65           33753499
# 137        1201107946
# 209           2882482
# 281          39543149
# 353             51391

# %%
# Load 2016 world population data
pop_2016_df = population_df.loc[population_df["Year"] == 2016].copy()

pop_2016_df = pop_2016_df[["Country name","65+ years","25-64 years","15-24 years","5-14 years","Under-5s"]]

pop_2016_df.rename(columns={"Country name":"Country",
                "65+ years":"Age 65+",
                "25-64 years":"Age 64-25",
                "15-24 years":"Age 24-15",
                "5-14 years":"Age 14-5",
                "Under-5s":"Age <5",}, inplace=True)

pop_2016_df["Total Population"] = pop_2016_df["Age 65+"] + pop_2016_df["Age 64-25"] + pop_2016_df["Age 24-15"] + pop_2016_df["Age 14-5"] + pop_2016_df["Age <5"]

pop_2016_df.head()
# Out:
#             Country   Age 65+  Age 64-25  Age 24-15   Age 14-5     Age <5  \
# 66      Afghanistan    830922   10565917    7472635    9872101    5894636
# 138     Africa (UN)  40972680  447982200  236038450  314563100  192555140
# 210         Albania    402525    1484617     481271     347008     165643
# 282         Algeria   2153970   20006912    6304417    7133967    4740063
# 354  American Samoa      2633      22731       9519      10431       5154
#
#      Total Population
# 66           34636211
# 138        1232111570
# 210           2881064
# 282          40339329
# 354             50468

# %%
# Load 2017 world population data
pop_2017_df = population_df.loc[population_df["Year"] == 2017].copy()

pop_2017_df = pop_2017_df[["Country name","65+ years","25-64 years","15-24 years","5-14 years","Under-5s"]]

pop_2017_df.rename(columns={"Country name":"Country",
                "65+ years":"Age 65+",
                "25-64 years":"Age 64-25",
                "15-24 years":"Age 24-15",
                "5-14 years":"Age 14-5",
                "Under-5s":"Age <5",}, inplace=True)

pop_2017_df["Total Population"] = pop_2017_df["Age 65+"] + pop_2017_df["Age 64-25"] + pop_2017_df["Age 24-15"] + pop_2017_df["Age 14-5"] + pop_2017_df["Age <5"]

pop_2017_df.head()
# Out:
#             Country   Age 65+  Age 64-25  Age 24-15   Age 14-5     Age <5  \
# 67      Afghanistan    855378   10980503    7725721   10053080    6028737
# 139     Africa (UN)  42420260  460973440  241416940  322917950  195605150
# 211         Albania    414664    1496452     465994     340245     162006
# 283         Algeria   2262312   20430718    6164044    7449846    4829627
# 355  American Samoa      2723      22735       9059      10040       4929
#
#      Total Population
# 67           35643419
# 139        1263333740
# 211           2879361
# 283          41136547
# 355             49486

# %%
# Load 2018 world population data
pop_2018_df = population_df.loc[population_df["Year"] == 2018].copy()

pop_2018_df = pop_2018_df[["Country name","65+ years","25-64 years","15-24 years","5-14 years","Under-5s"]]

pop_2018_df.rename(columns={"Country name":"Country",
                "65+ years":"Age 65+",
                "25-64 years":"Age 64-25",
                "15-24 years":"Age 24-15",
                "5-14 years":"Age 14-5",
                "Under-5s":"Age <5",}, inplace=True)

pop_2018_df["Total Population"] = pop_2018_df["Age 65+"] + pop_2018_df["Age 64-25"] + pop_2018_df["Age 24-15"] + pop_2018_df["Age 14-5"] + pop_2018_df["Age <5"]

pop_2018_df.head()
# Out:
#             Country   Age 65+  Age 64-25  Age 24-15   Age 14-5     Age <5  \
# 68      Afghanistan    883086   11425808    7975800   10254738    6147355
# 140     Africa (UN)  43958980  474340160  247195550  331170900  198599410
# 212         Albania    427248    1507915     450372     334807     156677
# 284         Algeria   2377431   20831888    6052352    7774388    4890948
# 356  American Samoa      2809      22757       8551       9632       4696
#
#      Total Population
# 68           36686787
# 140        1295265000
# 212           2877019
# 284          41927007
# 356             48445

# %%
# Load 2019 world population data
pop_2019_df = population_df.loc[population_df["Year"] == 2019].copy()

pop_2019_df = pop_2019_df[["Country name","65+ years","25-64 years","15-24 years","5-14 years","Under-5s"]]

pop_2019_df.rename(columns={"Country name":"Country",
                "65+ years":"Age 65+",
                "25-64 years":"Age 64-25",
                "15-24 years":"Age 24-15",
                "5-14 years":"Age 14-5",
                "Under-5s":"Age <5",}, inplace=True)

pop_2019_df["Total Population"] = pop_2019_df["Age 65+"] + pop_2019_df["Age 64-25"] + pop_2019_df["Age 24-15"] + pop_2019_df["Age 14-5"] + pop_2019_df["Age <5"]

pop_2019_df.head()
# Out:
#             Country   Age 65+  Age 64-25  Age 24-15   Age 14-5     Age <5  \
# 69      Afghanistan    913175   11905732    8221968   10466230    6262390
# 141     Africa (UN)  45566652  487927400  253363740  339280830  201562530
# 213         Albania    441159    1517906     433393     330958     150467
# 285         Algeria   2500418   21209136    5982387    8091421    4922011
# 357  American Samoa      2897      22731       8039       9214       4460
#
#      Total Population
# 69           37769495
# 141        1327701152
# 213           2873883
# 285          42705373
# 357             47341

# %%
# Load 2020 world population data
pop_2020_df = population_df.loc[population_df["Year"] == 2020].copy()

pop_2020_df = pop_2020_df[["Country name","65+ years","25-64 years","15-24 years","5-14 years","Under-5s"]]

pop_2020_df.rename(columns={"Country name":"Country",
                "65+ years":"Age 65+",
                "25-64 years":"Age 64-25",
                "15-24 years":"Age 24-15",
                "5-14 years":"Age 14-5",
                "Under-5s":"Age <5",}, inplace=True)

pop_2020_df["Total Population"] = pop_2020_df["Age 65+"] + pop_2020_df["Age 64-25"] + pop_2020_df["Age 24-15"] + pop_2020_df["Age 14-5"] + pop_2020_df["Age <5"]

pop_2020_df.head()
# Out:
#             Country   Age 65+  Age 64-25  Age 24-15   Age 14-5     Age <5  \
# 70      Afghanistan    941944   12466593    8490775   10697827    6375097
# 142     Africa (UN)  47073532  501843800  260032540  347239260  204488060
# 214         Albania    453597    1524674     416365     327068     145146
# 286         Algeria   2614694   21554976    5965332    8402270    4914397
# 358  American Samoa      2989      22632       7567       8793       4235
#
#      Total Population
# 70           38972236
# 142        1360677192
# 214           2866850
# 286          43451669
# 358             46216

# %%
# Load 2021 world population data
pop_2021_df = population_df.loc[population_df["Year"] == 2021].copy()

pop_2021_df = pop_2021_df[["Country name","65+ years","25-64 years","15-24 years","5-14 years","Under-5s"]]

pop_2021_df.rename(columns={"Country name":"Country",
                "65+ years":"Age 65+",
                "25-64 years":"Age 64-25",
                "15-24 years":"Age 24-15",
                "5-14 years":"Age 14-5",
                "Under-5s":"Age <5",}, inplace=True)

pop_2021_df["Total Population"] = pop_2021_df["Age 65+"] + pop_2021_df["Age 64-25"] + pop_2021_df["Age 24-15"] + pop_2021_df["Age 14-5"] + pop_2021_df["Age <5"]

pop_2021_df.head()
# Out:
#             Country   Age 65+  Age 64-25  Age 24-15   Age 14-5     Age <5  \
# 71      Afghanistan    964016   12995277    8727158   10922455    6490554
# 143     Africa (UN)  48363104  515889920  267091980  354882100  207449340
# 215         Albania    463442    1527360     399113     323402     141393
# 287         Algeria   2731079   21871300    6007613    8697129    4870841
# 359  American Samoa      3088      22433       7141       8365       4029
#
#      Total Population
# 71           40099460
# 143        1393676444
# 215           2854710
# 287          44177962
# 359             45056

# %%
#merge 2015 happiness data with education data and population data
WHI_ed_pop_2015_df = WHI_ed_2015_df.merge(pop_2015_df, on="Country", how="left")

WHI_ed_pop_2015_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score      GDP   Family  \
# 0  Switzerland               1            7.587  1.39651  1.34951
# 1      Iceland               2            7.561  1.30232  1.40223
# 2      Denmark               3            7.527  1.32548  1.36058
# 3       Norway               4            7.522  1.45900  1.33095
# 4       Canada               5            7.427  1.32629  1.32261
#
#    Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure  \
# 0          0.94143  0.66557     0.41978     0.29678                4.93845
# 1          0.94784  0.62877     0.14145     0.43630                7.45797
# 2          0.87464  0.64938     0.48357     0.34139                    NaN
# 3          0.88521  0.66973     0.36503     0.34699                7.56933
# 4          0.90563  0.63297     0.32957     0.45811                    NaN
#
#      Age 65+   Age 64-25  Age 24-15   Age 14-5     Age <5  Total Population
# ...

# %%
#merge 2016 happiness data with education data and population data
WHI_ed_pop_2016_df = WHI_ed_2016_df.merge(pop_2016_df, on="Country", how="left")

WHI_ed_pop_2016_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score      GDP   Family  \
# 0      Denmark               1            7.526  1.44178  1.16374
# 1  Switzerland               2            7.509  1.52733  1.14524
# 2      Iceland               3            7.501  1.42666  1.18326
# 3       Norway               4            7.498  1.57744  1.12690
# 4      Finland               5            7.413  1.40598  1.13464
#
#    Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure  \
# 0          0.79504  0.57941     0.44453     0.36171                    NaN
# 1          0.86303  0.58557     0.41203     0.28083                4.92646
# 2          0.86733  0.56624     0.14975     0.47678                7.43220
# 3          0.79579  0.59609     0.35776     0.37895                8.03055
# 4          0.81091  0.57104     0.41004     0.25492                6.85153
#
#      Age 65+  Age 64-25  Age 24-15  Age 14-5    Age <5  Total Population
# ...

# %%
#merge 2017 happiness data with education data and population data
WHI_ed_pop_2017_df = WHI_ed_2017_df.merge(pop_2017_df, on="Country", how="left")

WHI_ed_pop_2017_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score       GDP    Family  \
# 0       Norway               1            7.537  1.616463  1.533524
# 1      Denmark               2            7.522  1.482383  1.551122
# 2      Iceland               3            7.504  1.480633  1.610574
# 3  Switzerland               4            7.494  1.564980  1.516912
# 4      Finland               5            7.469  1.443572  1.540247
#
#    Life Expectancy   Freedom  Corruption  Generosity  Education Expenditure  \
# 0         0.796667  0.635423    0.315964    0.362012                7.91198
# 1         0.792566  0.626007    0.400770    0.355280                7.75244
# 2         0.833552  0.627163    0.153527    0.475540                7.58386
# 3         0.858131  0.620071    0.367007    0.290549                4.95157
# 4         0.809158  0.617951    0.382612    0.245483                6.36311
#
#      Age 65+  Age 64-25  Age 24-15  Age 14-5    Age <5  Total Population
# ...

# %%
#merge 2018 happiness data with education data and population data
WHI_ed_pop_2018_df = WHI_ed_2018_df.merge(pop_2018_df, on="Country", how="left")

WHI_ed_pop_2018_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0      Finland               1            7.632  1.305   1.592
# 1       Norway               2            7.594  1.456   1.582
# 2      Denmark               3            7.555  1.351   1.590
# 3      Iceland               4            7.495  1.343   1.644
# 4  Switzerland               5            7.487  1.420   1.549
#
#    Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure  \
# 0            0.874    0.681       0.393       0.202                6.26930
# 1            0.861    0.686       0.340       0.286                7.64411
# 2            0.868    0.683       0.408       0.284                    NaN
# 3            0.914    0.677       0.138       0.353                7.57406
# 4            0.927    0.660       0.357       0.256                4.86094
#
#      Age 65+  Age 64-25  Age 24-15  Age 14-5    Age <5  Total Population
# ...

# %%
#merge 2019 happiness data with education data and population data
WHI_ed_pop_2019_df = WHI_ed_2019_df.merge(pop_2019_df, on="Country", how="left")

WHI_ed_pop_2019_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0      Finland               1            7.769  1.340   1.587
# 1      Denmark               2            7.600  1.383   1.573
# 2       Norway               3            7.554  1.488   1.582
# 3      Iceland               4            7.494  1.380   1.624
# 4  Netherlands               5            7.488  1.396   1.522
#
#    Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure  \
# 0            0.986    0.596       0.393       0.153                    NaN
# 1            0.996    0.592       0.410       0.252                    NaN
# 2            1.028    0.603       0.341       0.271                    NaN
# 3            1.026    0.591       0.118       0.354                    NaN
# 4            0.999    0.557       0.298       0.322                    NaN
#
#      Age 65+  Age 64-25  Age 24-15   Age 14-5    Age <5  Total Population
# ...

# %%
#merge 2020 happiness data with education data and population data
WHI_ed_pop_2020_df = WHI_ed_2020_df.merge(pop_2020_df, on="Country", how="left")

WHI_ed_pop_2020_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score       GDP    Family  \
# 0      Finland               1           7.8087  1.285190  1.499526
# 1      Denmark               2           7.6456  1.326949  1.503449
# 2  Switzerland               3           7.5599  1.390774  1.472403
# 3      Iceland               4           7.5045  1.326502  1.547567
# 4       Norway               5           7.4880  1.424207  1.495173
#
#    Life Expectancy   Freedom  Corruption  Generosity  Education Expenditure  \
# 0         0.961271  0.662317    0.477857    0.159670                    NaN
# 1         0.979333  0.665040    0.495260    0.242793                    NaN
# 2         1.040533  0.628954    0.407946    0.269056                    NaN
# 3         1.000843  0.661981    0.144541    0.362330                    NaN
# 4         1.008072  0.670201    0.434101    0.287985                    NaN
#
#      Age 65+  Age 64-25  Age 24-15  Age 14-5    Age <5  Total Population
# ...

# %%
#merge 2021 happiness data with education data and population data
WHI_ed_pop_2021_df = WHI_ed_2021_df.merge(pop_2021_df, on="Country", how="left")

WHI_ed_pop_2021_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0      Finland               1            7.842  1.446   1.106
# 1      Denmark               2            7.620  1.502   1.108
# 2  Switzerland               3            7.571  1.566   1.079
# 3      Iceland               4            7.554  1.482   1.172
# 4  Netherlands               5            7.464  1.501   1.079
#
#    Life Expectancy  Freedom  Corruption  Generosity Education Expenditure  \
# 0            0.741    0.691       0.481       0.124                   NaN
# 1            0.763    0.686       0.485       0.208                   NaN
# 2            0.816    0.653       0.413       0.204                   NaN
# 3            0.772    0.698       0.170       0.293                   NaN
# 4            0.753    0.647       0.384       0.302                   NaN
#
#      Age 65+  Age 64-25  Age 24-15   Age 14-5    Age <5  Total Population
# ...

# %%
# Load world migration into data
migration_into_df = pd.read_csv("../../final_destination_data.csv")

migration_into_df["Type"] = migration_into_df["Year"].str.split(" ").str[1]
migration_into_df["Year"] = migration_into_df["Year"].str.split(" ").str[0]

migration_into_df.head()
# Out:
#    Destination  Year  Migrating into the country      Type
# 0  Afghanistan  2015                      339432  Combined
# 1  Afghanistan  2020                      144098  Combined
# 2  Afghanistan  2015                      171550     Males
# 3  Afghanistan  2020                       69189     Males
# 4  Afghanistan  2015                      167882   Females

# %%
# Load world migration from data
migration_from_df = pd.read_csv("../../final_origin_data.csv")

migration_from_df["Type"] = migration_from_df["Year"].str.split(" ").str[1]
migration_from_df["Year"] = migration_from_df["Year"].str.split(" ").str[0]

migration_from_df.head()
# Out:
#    Destination  Year  Migrating from the country      Type
# 0  Afghanistan  2015                     5401107  Combined
# 1  Afghanistan  2020                     5854088  Combined
# 2  Afghanistan  2015                     2903020     Males
# 3  Afghanistan  2020                     3226466     Males
# 4  Afghanistan  2015                     2498087   Females

# %%
#read naming data to match based data
migration_into_df["Destination"] = migration_into_df["Destination"].replace({"Bolivia, Plurinational State of": "Bolivia",
    "Bonaire, Sint Eustatius and Saba":"Bonaire Sint Eustatius and Saba",
    "Falkland Islands (Malvinas)":"Falkland Islands",
    "Iran, Islamic Republic of":"Iran",
    "Korea, Republic of":"South Korea",
    "Lao People's Democratic Republic":"Laos",
    "Macedonia, the Former Yugoslav Republic of":"Macedonia",
    "Taiwan, Province of China":"Taiwan",
    "Tanzania, United Republic of":"Tanzania",
    "Venezuela, Bolivarian Republic of":"Venezuela",
    "Viet Nam":"Vietnam",
    "Micronesia":"Micronesia (country)",
    "Syrian Arab Republic":"Syria",
    "Russian Federation":"Russia",
    "Palestine, State of":"Palestinian Territories",
    "Côte d'Ivoire":"Ivory Coast",
    "Moldova, Republic of":"Moldova",
    "Somaliland region":"Somaliland region",
    "Congo, the Democratic Republic of the":"Congo (Kinshasa)",
    "Congo":"Congo (Brazzaville)",
    "Macedonia, the Former Yugoslav Republic of":"Macedonia",
    "Viet Nam": "Vietnam",
    "United States of America":"United States",
    "Czechia":"Czech Republic",
    "China, Taiwan Province of China":"Taiwan",
    "Republic of Korea":"South Korea",
    "Republic of Moldova":"Moldova",
    "Russian Federation":"Russia",
    "Cyprus":"North Cyprus",
    "North Macedonia":"Macedonia",
    "State of Palestine":"Palestinian Territories",
    "Democratic Republic of the Congo":"Congo (Kinshasa)",
    "Congo":"Congo (Brazzaville)",
    "United Republic of Tanzania":"Tanzania",
    "Côte d'Ivoire":"Ivory Coast",
    "Syrian Arab Republic":"Syria",
    "Venezuela (Bolivarian Republic of)":"Venezuela",
    "China, Hong Kong SAR":"Hong Kong",
    "China, Macao SAR":"Macao",
    "Bolivia (Plurinational State of)":"Bolivia",
    "Bonaire, Sint Eustatius and Saba":"Bonaire Sint Eustatius and Saba",
    "China, Taiwan Province of China":"Taiwan",
    "Dem. People's Republic of Korea":"North Korea",
    "Falkland Islands (Malvinas)":"Falkland Islands",
    "Iran (Islamic Republic of)":"Iran",
    "Lao People's Democratic Republic":"Laos",
    "Micronesia":"Micronesia (country)"
    })

# %%
#read naming data to match based data
migration_from_df["Destination"] = migration_from_df["Destination"].replace({"Bolivia, Plurinational State of": "Bolivia",
    "Bonaire, Sint Eustatius and Saba":"Bonaire Sint Eustatius and Saba",
    "Falkland Islands (Malvinas)":"Falkland Islands",
    "Iran, Islamic Republic of":"Iran",
    "Korea, Republic of":"South Korea",
    "Lao People's Democratic Republic":"Laos",
    "Macedonia, the Former Yugoslav Republic of":"Macedonia",
    "Taiwan, Province of China":"Taiwan",
    "Tanzania, United Republic of":"Tanzania",
    "Venezuela, Bolivarian Republic of":"Venezuela",
    "Viet Nam":"Vietnam",
    "Micronesia":"Micronesia (country)",
    "Syrian Arab Republic":"Syria",
    "Russian Federation":"Russia",
    "Palestine, State of":"Palestinian Territories",
    "Côte d'Ivoire":"Ivory Coast",
    "Moldova, Republic of":"Moldova",
    "Somaliland region":"Somalia",
    "Congo, the Democratic Republic of the":"Congo (Kinshasa)",
    "Congo":"Congo (Brazzaville)",
    "Macedonia, the Former Yugoslav Republic of":"Macedonia",
    "Viet Nam": "Vietnam",
    "United States of America":"United States",
    "Czechia":"Czech Republic",
    "China, Taiwan Province of China":"Taiwan",
    "Republic of Korea":"South Korea",
    "Republic of Moldova":"Moldova",
    "Russian Federation":"Russia",
    "Cyprus":"North Cyprus",
    "North Macedonia":"Macedonia",
    "State of Palestine":"Palestinian Territories",
    "Democratic Republic of the Congo":"Congo (Kinshasa)",
    "Congo":"Congo (Brazzaville)",
    "United Republic of Tanzania":"Tanzania",
    "Côte d'Ivoire":"Ivory Coast",
    "Syrian Arab Republic":"Syria",
    "Venezuela (Bolivarian Republic of)":"Venezuela",
    "China, Hong Kong SAR":"Hong Kong",
    "China, Macao SAR":"Macao",
    "Bolivia (Plurinational State of)":"Bolivia",
    "Bonaire, Sint Eustatius and Saba":"Bonaire Sint Eustatius and Saba",
    "China, Taiwan Province of China":"Taiwan",
    "Dem. People's Republic of Korea":"North Korea",
    "Falkland Islands (Malvinas)":"Falkland Islands",
    "Iran (Islamic Republic of)":"Iran",
    "Lao People's Democratic Republic":"Laos",
    "Micronesia":"Micronesia (country)"})

# %%
#migration into combined data 2015
migration_into_combined_2015_df = migration_into_df.loc[(migration_into_df["Year"] == "2015")&(migration_into_df["Type"] == "Combined")].copy()

migration_into_combined_2015_df = migration_into_combined_2015_df[["Destination","Migrating into the country"]]

migration_into_combined_2015_df.rename(columns={"Destination":"Country",
                "Migrating into the country":"Migrating into the country(combined)"}, inplace=True)
                
migration_into_combined_2015_df
# Out:
#                         Country  Migrating into the country(combined)
# 0                   Afghanistan                                339432
# 6                       Albania                                 52031
# 12                      Algeria                                239473
# 18               American Samoa                                 23513
# 24                      Andorra                                 42264
# ...                         ...                                   ...
# 1392  Wallis and Futuna Islands                                  2050
# 1398             Western Sahara                                  5179
# 1404                      Yemen                                379882
# 1410                     Zambia                                132107
# 1416                   Zimbabwe                                400482
#
# [237 rows x 2 columns]

# %%
#migration from combined data 2015
migration_from_combined_2015_df = migration_from_df.loc[(migration_from_df["Year"] == "2015")&(migration_from_df["Type"] == "Combined")].copy()

migration_from_combined_2015_df = migration_from_combined_2015_df[["Destination","Migrating from the country"]]

migration_from_combined_2015_df.rename(columns={"Destination":"Country",
                "Migrating from the country":"Migrating from the country(combined)"}, inplace=True)
                
migration_from_combined_2015_df
# Out:
#                         Country  Migrating from the country(combined)
# 0                   Afghanistan                               5401107
# 6                       Albania                               1143002
# 12                      Algeria                               1837346
# 18               American Samoa                                  1984
# 24                      Andorra                                  8753
# ...                         ...                                   ...
# 1392  Wallis and Futuna Islands                                 11227
# 1398             Western Sahara                                185885
# 1404                      Yemen                               1095240
# 1410                     Zambia                                184375
# 1416                   Zimbabwe                               1167205
#
# [237 rows x 2 columns]

# %%
#migration into male data 2015
migration_into_male_2015_df = migration_into_df.loc[(migration_into_df["Year"] == "2015")&(migration_into_df["Type"] == "Males")].copy()

migration_into_male_2015_df = migration_into_male_2015_df[["Destination","Migrating into the country"]]

migration_into_male_2015_df.rename(columns={"Destination":"Country",
                "Migrating into the country":"Migrating into the country(males)"}, inplace=True)
                
migration_into_male_2015_df
# Out:
#                         Country  Migrating into the country(males)
# 2                   Afghanistan                             171550
# 8                       Albania                              26517
# 14                      Algeria                             126522
# 20               American Samoa                              11998
# 26                      Andorra                              21485
# ...                         ...                                ...
# 1394  Wallis and Futuna Islands                               1035
# 1400             Western Sahara                               3059
# 1406                      Yemen                             199390
# 1412                     Zambia                              66651
# 1418                   Zimbabwe                             225653
#
# [237 rows x 2 columns]

# %%
#migration from male data 2015
migration_from_male_2015_df = migration_from_df.loc[(migration_from_df["Year"] == "2015")&(migration_from_df["Type"] == "Males")].copy()

migration_from_male_2015_df = migration_from_male_2015_df[["Destination","Migrating from the country"]]

migration_from_male_2015_df.rename(columns={"Destination":"Country",
                "Migrating from the country":"Migrating from the country(males)"}, inplace=True)
                
migration_from_male_2015_df
# Out:
#                         Country  Migrating from the country(males)
# 2                   Afghanistan                            2903020
# 8                       Albania                             576306
# 14                      Algeria                             986073
# 20               American Samoa                               1004
# 26                      Andorra                               4213
# ...                         ...                                ...
# 1394  Wallis and Futuna Islands                               5364
# 1400             Western Sahara                              98132
# 1406                      Yemen                             720626
# 1412                     Zambia                              86167
# 1418                   Zimbabwe                             602202
#
# [237 rows x 2 columns]

# %%
#migration into female data 2015
migration_into_female_2015_df = migration_into_df.loc[(migration_into_df["Year"] == "2015")&(migration_into_df["Type"] == "Females")].copy()

migration_into_female_2015_df = migration_into_female_2015_df[["Destination","Migrating into the country"]]

migration_into_female_2015_df.rename(columns={"Destination":"Country",
                "Migrating into the country":"Migrating into the country(females)"}, inplace=True)
                
migration_into_female_2015_df
# Out:
#                         Country  Migrating into the country(females)
# 4                   Afghanistan                               167882
# 10                      Albania                                25514
# 16                      Algeria                               112951
# 22               American Samoa                                11515
# 28                      Andorra                                20779
# ...                         ...                                  ...
# 1396  Wallis and Futuna Islands                                 1015
# 1402             Western Sahara                                 2120
# 1408                      Yemen                               180492
# 1414                     Zambia                                65456
# 1420                   Zimbabwe                               174829
#
# [237 rows x 2 columns]

# %%
#migration from female data 2015
migration_from_female_2015_df = migration_from_df.loc[(migration_from_df["Year"] == "2015")&(migration_from_df["Type"] == "Females")].copy()

migration_from_female_2015_df = migration_from_female_2015_df[["Destination","Migrating from the country"]]

migration_from_female_2015_df.rename(columns={"Destination":"Country",
                "Migrating from the country":"Migrating from the country(females)"}, inplace=True)
                
migration_from_female_2015_df
# Out:
#                         Country  Migrating from the country(females)
# 4                   Afghanistan                              2498087
# 10                      Albania                               566696
# 16                      Algeria                               851273
# 22               American Samoa                                  980
# 28                      Andorra                                 4540
# ...                         ...                                  ...
# 1396  Wallis and Futuna Islands                                 5863
# 1402             Western Sahara                                87753
# 1408                      Yemen                               374614
# 1414                     Zambia                                98208
# 1420                   Zimbabwe                               565003
#
# [237 rows x 2 columns]

# %%
#combining all migration into 2015 data
migration_into_combined_2015_df["Migrating into the country(males)"] = migration_into_male_2015_df["Migrating into the country(males)"].values
migration_into_combined_2015_df["Migrating into the country(females)"] = migration_into_female_2015_df["Migrating into the country(females)"].values

migration_into_combined_2015_df.head()
# Out:
#            Country  Migrating into the country(combined)  \
# 0      Afghanistan                                339432
# 6          Albania                                 52031
# 12         Algeria                                239473
# 18  American Samoa                                 23513
# 24         Andorra                                 42264
#
#     Migrating into the country(males)  Migrating into the country(females)
# 0                              171550                               167882
# 6                               26517                                25514
# 12                             126522                               112951
# 18                              11998                                11515
# 24                              21485                                20779

# %%
#combining all migration from 2015 data
migration_from_combined_2015_df["Migrating from the country(males)"] = migration_from_male_2015_df["Migrating from the country(males)"].values
migration_from_combined_2015_df["Migrating from the country(females)"] = migration_from_female_2015_df["Migrating from the country(females)"].values

migration_from_combined_2015_df.head()
# Out:
#            Country  Migrating from the country(combined)  \
# 0      Afghanistan                               5401107
# 6          Albania                               1143002
# 12         Algeria                               1837346
# 18  American Samoa                                  1984
# 24         Andorra                                  8753
#
#     Migrating from the country(males)  Migrating from the country(females)
# 0                             2903020                              2498087
# 6                              576306                               566696
# 12                             986073                               851273
# 18                               1004                                  980
# 24                               4213                                 4540

# %%
#migration into combined data 2020
migration_into_combined_2020_df = migration_into_df.loc[(migration_into_df["Year"] == "2020")&(migration_into_df["Type"] == "Combined")].copy()

migration_into_combined_2020_df = migration_into_combined_2020_df[["Destination","Migrating into the country"]]

migration_into_combined_2020_df.rename(columns={"Destination":"Country",
                "Migrating into the country":"Migrating into the country(combined)"}, inplace=True)
                
migration_into_combined_2020_df
# Out:
#                         Country  Migrating into the country(combined)
# 1                   Afghanistan                                144098
# 7                       Albania                                 48810
# 13                      Algeria                                250378
# 19               American Samoa                                 23608
# 25                      Andorra                                 45574
# ...                         ...                                   ...
# 1393  Wallis and Futuna Islands                                  2040
# 1399             Western Sahara                                  5424
# 1405                      Yemen                                387113
# 1411                     Zambia                                187955
# 1417                   Zimbabwe                                416141
#
# [237 rows x 2 columns]

# %%
#migration from combined data 2020
migration_from_combined_2020_df = migration_from_df.loc[(migration_from_df["Year"] == "2020")&(migration_into_df["Type"] == "Combined")].copy()

migration_from_combined_2020_df = migration_from_combined_2020_df[["Destination","Migrating from the country"]]

migration_from_combined_2020_df.rename(columns={"Destination":"Country",
                "Migrating from the country":"Migrating from the country(combined)"}, inplace=True)
                
migration_from_combined_2020_df
# Out:
#                         Country  Migrating from the country(combined)
# 1                   Afghanistan                               5854088
# 7                       Albania                               1250608
# 13                      Algeria                               2023250
# 19               American Samoa                                  1854
# 25                      Andorra                                 11146
# ...                         ...                                   ...
# 1393  Wallis and Futuna Islands                                 11917
# 1399             Western Sahara                                194932
# 1405                      Yemen                               1301166
# 1411                     Zambia                                200703
# 1417                   Zimbabwe                               1243461
#
# [237 rows x 2 columns]

# %%
#migration into male data 2020
migration_into_male_2020_df = migration_into_df.loc[(migration_into_df["Year"] == "2020")&(migration_into_df["Type"] == "Males")].copy()

migration_into_male_2020_df = migration_into_male_2020_df[["Destination","Migrating into the country"]]

migration_into_male_2020_df.rename(columns={"Destination":"Country",
                "Migrating into the country":"Migrating into the country(males)"}, inplace=True)
                
migration_into_male_2020_df
# Out:
#                         Country  Migrating into the country(males)
# 3                   Afghanistan                              69189
# 9                       Albania                              24908
# 15                      Algeria                             132142
# 21               American Samoa                              12047
# 27                      Andorra                              23333
# ...                         ...                                ...
# 1395  Wallis and Futuna Islands                               1030
# 1401             Western Sahara                               3205
# 1407                      Yemen                             223512
# 1413                     Zambia                              97556
# 1419                   Zimbabwe                             236561
#
# [237 rows x 2 columns]

# %%
#migration from male data 2020
migration_from_male_2020_df = migration_from_df.loc[(migration_from_df["Year"] == "2020")&(migration_from_df["Type"] == "Males")].copy()

migration_from_male_2020_df = migration_from_male_2020_df[["Destination","Migrating from the country"]]

migration_from_male_2020_df.rename(columns={"Destination":"Country",
                "Migrating from the country":"Migrating from the country(males)"}, inplace=True)
                
migration_from_male_2020_df
# Out:
#                         Country  Migrating from the country(males)
# 3                   Afghanistan                            3226466
# 9                       Albania                             642717
# 15                      Algeria                            1086178
# 21               American Samoa                                936
# 27                      Andorra                               5316
# ...                         ...                                ...
# 1395  Wallis and Futuna Islands                               5673
# 1401             Western Sahara                             102851
# 1407                      Yemen                             847302
# 1413                     Zambia                              93623
# 1419                   Zimbabwe                             641258
#
# [237 rows x 2 columns]

# %%
#migration into female data 2020
migration_into_female_2020_df = migration_into_df.loc[(migration_into_df["Year"] == "2020")&(migration_into_df["Type"] == "Females")].copy()

migration_into_female_2020_df = migration_into_female_2020_df[["Destination","Migrating into the country"]]

migration_into_female_2020_df.rename(columns={"Destination":"Country",
                "Migrating into the country":"Migrating into the country(females)"}, inplace=True)
                
migration_into_female_2020_df
# Out:
#                         Country  Migrating into the country(females)
# 5                   Afghanistan                                74909
# 11                      Albania                                23902
# 17                      Algeria                               118236
# 23               American Samoa                                11561
# 29                      Andorra                                22241
# ...                         ...                                  ...
# 1397  Wallis and Futuna Islands                                 1010
# 1403             Western Sahara                                 2219
# 1409                      Yemen                               163601
# 1415                     Zambia                                90399
# 1421                   Zimbabwe                               179580
#
# [237 rows x 2 columns]

# %%
#migration from female data 2020
migration_from_female_2020_df = migration_from_df.loc[(migration_from_df["Year"] == "2020")&(migration_from_df["Type"] == "Females")].copy()

migration_from_female_2020_df = migration_from_female_2020_df[["Destination","Migrating from the country"]]

migration_from_female_2020_df.rename(columns={"Destination":"Country",
                "Migrating from the country":"Migrating from the country(females)"}, inplace=True)
                
migration_from_female_2020_df
# Out:
#                         Country  Migrating from the country(females)
# 5                   Afghanistan                              2627622
# 11                      Albania                               607891
# 17                      Algeria                               937072
# 23               American Samoa                                  918
# 29                      Andorra                                 5830
# ...                         ...                                  ...
# 1397  Wallis and Futuna Islands                                 6244
# 1403             Western Sahara                                92081
# 1409                      Yemen                               453864
# 1415                     Zambia                               107080
# 1421                   Zimbabwe                               602203
#
# [237 rows x 2 columns]

# %%
#combining all migration into 2020 data
migration_into_combined_2020_df["Migrating into the country(males)"] = migration_into_male_2020_df["Migrating into the country(males)"].values
migration_into_combined_2020_df["Migrating into the country(females)"] = migration_into_female_2020_df["Migrating into the country(females)"].values

migration_into_combined_2020_df.head()
# Out:
#            Country  Migrating into the country(combined)  \
# 1      Afghanistan                                144098
# 7          Albania                                 48810
# 13         Algeria                                250378
# 19  American Samoa                                 23608
# 25         Andorra                                 45574
#
#     Migrating into the country(males)  Migrating into the country(females)
# 1                               69189                                74909
# 7                               24908                                23902
# 13                             132142                               118236
# 19                              12047                                11561
# 25                              23333                                22241

# %%
#combining all migration from 2020 data
migration_from_combined_2020_df["Migrating from the country(males)"] = migration_from_male_2020_df["Migrating from the country(males)"].values
migration_from_combined_2020_df["Migrating from the country(females)"] = migration_from_female_2020_df["Migrating from the country(females)"].values

migration_from_combined_2020_df.head()
# Out:
#            Country  Migrating from the country(combined)  \
# 1      Afghanistan                               5854088
# 7          Albania                               1250608
# 13         Algeria                               2023250
# 19  American Samoa                                  1854
# 25         Andorra                                 11146
#
#     Migrating from the country(males)  Migrating from the country(females)
# 1                             3226466                              2627622
# 7                              642717                               607891
# 13                            1086178                               937072
# 19                                936                                  918
# 25                               5316                                 5830

# %%
#merge 2015 happiness data with education data and population data
all_2015_df = WHI_ed_pop_2015_df.merge(migration_into_combined_2015_df, on="Country", how="left")
all_2015_df = all_2015_df.merge(migration_from_combined_2015_df, on="Country", how="left")

all_2015_df["Year"] = 2015

all_2015_df
# Out:
#          Country  Happiness Rank  Happiness Score      GDP   Family  \
# 0    Switzerland               1            7.587  1.39651  1.34951
# 1        Iceland               2            7.561  1.30232  1.40223
# 2        Denmark               3            7.527  1.32548  1.36058
# 3         Norway               4            7.522  1.45900  1.33095
# 4         Canada               5            7.427  1.32629  1.32261
# ..           ...             ...              ...      ...      ...
# 153       Rwanda             154            3.465  0.22208  0.77370
# 154        Benin             155            3.340  0.28665  0.35386
# 155        Syria             156            3.006  0.66320  0.47489
# 156      Burundi             157            2.905  0.01530  0.41587
# 157         Togo             158            2.839  0.20868  0.13995
#
#      Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure  \
# ...

# %%
# adding education expenditure column to 2016 data
all_2016_df = WHI_ed_pop_2016_df.copy()
all_2016_df["Migrating into the country(combined)"] = "NaN"
all_2016_df["Migrating into the country(males)"] = "NaN"
all_2016_df["Migrating into the country(females)"] = "NaN"

all_2016_df["Migrating from the country(combined)"] = "NaN"
all_2016_df["Migrating from the country(males)"] = "NaN"
all_2016_df["Migrating from the country(females)"] = "NaN"

all_2016_df["Year"] = 2016


all_2016_df
# Out:
#          Country  Happiness Rank  Happiness Score      GDP   Family  \
# 0        Denmark               1            7.526  1.44178  1.16374
# 1    Switzerland               2            7.509  1.52733  1.14524
# 2        Iceland               3            7.501  1.42666  1.18326
# 3         Norway               4            7.498  1.57744  1.12690
# 4        Finland               5            7.413  1.40598  1.13464
# ..           ...             ...              ...      ...      ...
# 152        Benin             153            3.484  0.39499  0.10419
# 153  Afghanistan             154            3.360  0.38227  0.11037
# 154         Togo             155            3.303  0.28123  0.00000
# 155        Syria             156            3.069  0.74719  0.14866
# 156      Burundi             157            2.905  0.06831  0.23442
#
#      Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure  \
# ...

# %%
# adding education expenditure column to 2017 data
all_2017_df = WHI_ed_pop_2017_df.copy()
all_2017_df["Migrating into the country(combined)"] = "NaN"
all_2017_df["Migrating into the country(males)"] = "NaN"
all_2017_df["Migrating into the country(females)"] = "NaN"

all_2017_df["Migrating from the country(combined)"] = "NaN"
all_2017_df["Migrating from the country(males)"] = "NaN"
all_2017_df["Migrating from the country(females)"] = "NaN"

all_2017_df["Year"] = 2017

all_2017_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score       GDP    Family  \
# 0       Norway               1            7.537  1.616463  1.533524
# 1      Denmark               2            7.522  1.482383  1.551122
# 2      Iceland               3            7.504  1.480633  1.610574
# 3  Switzerland               4            7.494  1.564980  1.516912
# 4      Finland               5            7.469  1.443572  1.540247
#
#    Life Expectancy   Freedom  Corruption  Generosity  Education Expenditure  \
# 0         0.796667  0.635423    0.315964    0.362012                7.91198
# 1         0.792566  0.626007    0.400770    0.355280                7.75244
# 2         0.833552  0.627163    0.153527    0.475540                7.58386
# 3         0.858131  0.620071    0.367007    0.290549                4.95157
# 4         0.809158  0.617951    0.382612    0.245483                6.36311
#
#    ...  Age 14-5    Age <5  Total Population  \
# 0  ...  636857.0  301558.0         5277396.0
# ...

# %%
# adding education expenditure column to 2018 data
all_2018_df = WHI_ed_pop_2018_df.copy()
all_2018_df["Migrating into the country(combined)"] = "NaN"
all_2018_df["Migrating into the country(males)"] = "NaN"
all_2018_df["Migrating into the country(females)"] = "NaN"

all_2018_df["Migrating from the country(combined)"] = "NaN"
all_2018_df["Migrating from the country(males)"] = "NaN"
all_2018_df["Migrating from the country(females)"] = "NaN"

all_2018_df["Year"] = 2018

all_2018_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0      Finland               1            7.632  1.305   1.592
# 1       Norway               2            7.594  1.456   1.582
# 2      Denmark               3            7.555  1.351   1.590
# 3      Iceland               4            7.495  1.343   1.644
# 4  Switzerland               5            7.487  1.420   1.549
#
#    Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure  \
# 0            0.874    0.681       0.393       0.202                6.26930
# 1            0.861    0.686       0.340       0.286                7.64411
# 2            0.868    0.683       0.408       0.284                    NaN
# 3            0.914    0.677       0.138       0.353                7.57406
# 4            0.927    0.660       0.357       0.256                4.86094
#
#    ...  Age 14-5    Age <5  Total Population  \
# 0  ...  613239.0  273118.0         5515465.0
# ...

# %%
# adding education expenditure column to 2019 data
all_2019_df = WHI_ed_pop_2019_df.copy()
all_2019_df["Migrating into the country(combined)"] = "NaN"
all_2019_df["Migrating into the country(males)"] = "NaN"
all_2019_df["Migrating into the country(females)"] = "NaN"

all_2019_df["Migrating from the country(combined)"] = "NaN"
all_2019_df["Migrating from the country(males)"] = "NaN"
all_2019_df["Migrating from the country(females)"] = "NaN"

all_2019_df["Year"] = 2019

all_2019_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0      Finland               1            7.769  1.340   1.587
# 1      Denmark               2            7.600  1.383   1.573
# 2       Norway               3            7.554  1.488   1.582
# 3      Iceland               4            7.494  1.380   1.624
# 4  Netherlands               5            7.488  1.396   1.522
#
#    Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure  \
# 0            0.986    0.596       0.393       0.153                    NaN
# 1            0.996    0.592       0.410       0.252                    NaN
# 2            1.028    0.603       0.341       0.271                    NaN
# 3            1.026    0.591       0.118       0.354                    NaN
# 4            0.999    0.557       0.298       0.322                    NaN
#
#    ...   Age 14-5    Age <5  Total Population  \
# 0  ...   614840.0  261828.0         5521539.0
# ...

# %%
#merge 2020 happiness data with migration into data 
all_2020_df = WHI_ed_pop_2020_df.merge(migration_into_combined_2020_df, on="Country", how="left")
all_2020_df = all_2020_df.merge(migration_from_combined_2020_df, on="Country", how="left")

all_2020_df["Year"] = 2020

all_2020_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score       GDP    Family  \
# 0      Finland               1           7.8087  1.285190  1.499526
# 1      Denmark               2           7.6456  1.326949  1.503449
# 2  Switzerland               3           7.5599  1.390774  1.472403
# 3      Iceland               4           7.5045  1.326502  1.547567
# 4       Norway               5           7.4880  1.424207  1.495173
#
#    Life Expectancy   Freedom  Corruption  Generosity  Education Expenditure  \
# 0         0.961271  0.662317    0.477857    0.159670                    NaN
# 1         0.979333  0.665040    0.495260    0.242793                    NaN
# 2         1.040533  0.628954    0.407946    0.269056                    NaN
# 3         1.000843  0.661981    0.144541    0.362330                    NaN
# 4         1.008072  0.670201    0.434101    0.287985                    NaN
#
#    ...  Age 14-5    Age <5  Total Population  \
# 0  ...  614505.0  251482.0         5529468.0
# ...

# %%
# adding education expenditure column to 2021 data
all_2021_df = WHI_ed_pop_2021_df.copy()
all_2021_df["Migrating into the country(combined)"] = "NaN"
all_2021_df["Migrating into the country(males)"] = "NaN"
all_2021_df["Migrating into the country(females)"] = "NaN"

all_2021_df["Migrating from the country(combined)"] = "NaN"
all_2021_df["Migrating from the country(males)"] = "NaN"
all_2021_df["Migrating from the country(females)"] = "NaN"
all_2021_df["Year"] = 2021

all_2021_df = all_2021_df.astype({"Education Expenditure": float})


all_2021_df.head()
# Out:
#        Country  Happiness Rank  Happiness Score    GDP  Family  \
# 0      Finland               1            7.842  1.446   1.106
# 1      Denmark               2            7.620  1.502   1.108
# 2  Switzerland               3            7.571  1.566   1.079
# 3      Iceland               4            7.554  1.482   1.172
# 4  Netherlands               5            7.464  1.501   1.079
#
#    Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure  \
# 0            0.741    0.691       0.481       0.124                    NaN
# 1            0.763    0.686       0.485       0.208                    NaN
# 2            0.816    0.653       0.413       0.204                    NaN
# 3            0.772    0.698       0.170       0.293                    NaN
# 4            0.753    0.647       0.384       0.302                    NaN
#
#    ...   Age 14-5    Age <5  Total Population  \
# 0  ...   610484.0  243643.0         5535982.0
# ...

# %%
all_dfs = [all_2015_df, all_2016_df, all_2017_df, all_2018_df, all_2019_df, all_2020_df, all_2021_df]
all_df = pd.concat(all_dfs, axis=0)
all_df
# Out:
#          Country  Happiness Rank  Happiness Score      GDP   Family  \
# 0    Switzerland               1            7.587  1.39651  1.34951
# 1        Iceland               2            7.561  1.30232  1.40223
# 2        Denmark               3            7.527  1.32548  1.36058
# 3         Norway               4            7.522  1.45900  1.33095
# 4         Canada               5            7.427  1.32629  1.32261
# ..           ...             ...              ...      ...      ...
# 144      Lesotho             145            3.512  0.45100  0.73100
# 145     Botswana             146            3.467  1.09900  0.72400
# 146       Rwanda             147            3.415  0.36400  0.20200
# 147     Zimbabwe             148            3.145  0.45700  0.64900
# 148  Afghanistan             149            2.523  0.37000  0.00000
#
#      Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure  \
# ...

# %%
all_df["Country"] = all_df["Country"].str.strip('"')

all_df["Country"]=all_df["Country"].replace({"Taiwan Province of China":"Taiwan",
    "Trinidad & Tobago":"Trinidad and Tobago",
    "North Macedonia":"Macedonia",
    "Somaliland region":"Somalia",
    "Somaliland Region":"Somalia",
    "Hong Kong S.A.R., China":"Hong Kong"})

# %%
iso_code_df = pd.read_csv("../Raw Data/iso_code.csv")
iso_code_df.head()
# Out:
#              Name Code
# 0     Afghanistan   AF
# 1   Åland Islands   AX
# 2         Albania   AL
# 3         Algeria   DZ
# 4  American Samoa   AS

# %%
iso_code_df["Name"] = iso_code_df["Name"].str.strip('"')

# %%
#renaming data to match based data
iso_code_df["Name"] = iso_code_df["Name"].replace({"Bolivia, Plurinational State of": "Bolivia",
    "Bonaire, Sint Eustatius and Saba":"Bonaire Sint Eustatius and Saba",
    "Falkland Islands (Malvinas)":"Falkland Islands",
    "Iran, Islamic Republic of":"Iran",
    "Korea, Republic of":"South Korea",
    "Lao People's Democratic Republic":"Laos",
    "Macedonia, the Former Yugoslav Republic of":"Macedonia",
    "Taiwan, Province of China":"Taiwan",
    "Tanzania, United Republic of":"Tanzania",
    "Venezuela, Bolivarian Republic of":"Venezuela",
    "Viet Nam":"Vietnam",
    "Micronesia":"Micronesia (country)",
    "Syrian Arab Republic":"Syria",
    "Russian Federation":"Russia",
    "Palestine, State of":"Palestinian Territories",
    "Côte d'Ivoire":"Ivory Coast",
    "Moldova, Republic of":"Moldova",
    "Somaliland region":"Somalia",
    "Congo, the Democratic Republic of the":"Congo (Kinshasa)",
    "Congo":"Congo (Brazzaville)",
    "Macedonia, the Former Yugoslav Republic of":"Macedonia"})

iso_code_df.rename(columns={"Name":"Country"}, inplace=True)

iso_code_df
# Out:
#                Country Code
# 0          Afghanistan   AF
# 1        Åland Islands   AX
# 2              Albania   AL
# 3              Algeria   DZ
# 4       American Samoa   AS
# ..                 ...  ...
# 244  Wallis and Futuna   WF
# 245     Western Sahara   EH
# 246              Yemen   YE
# 247             Zambia   ZM
# 248           Zimbabwe   ZW
#
# [249 rows x 2 columns]

# %%
new_row1 = {"Country": "Kosovo", "Code": "XK"}
new_row2 = {"Country": "North Cyprus", "Code": "MK"}
new_row3 = {"Country": "Namibia", "Code": "NA"}
 
iso_code_df.loc[len(iso_code_df)] = new_row1
iso_code_df.loc[len(iso_code_df)] = new_row2
iso_code_df.loc[len(iso_code_df)] = new_row3

# %%
all_df = all_df.merge(iso_code_df, on="Country", how="left")
all_df
# Out:
#           Country  Happiness Rank  Happiness Score      GDP   Family  \
# 0     Switzerland               1            7.587  1.39651  1.34951
# 1         Iceland               2            7.561  1.30232  1.40223
# 2         Denmark               3            7.527  1.32548  1.36058
# 3          Norway               4            7.522  1.45900  1.33095
# 4          Canada               5            7.427  1.32629  1.32261
# ...           ...             ...              ...      ...      ...
# 1085      Lesotho             145            3.512  0.45100  0.73100
# 1086     Botswana             146            3.467  1.09900  0.72400
# 1087       Rwanda             147            3.415  0.36400  0.20200
# 1088     Zimbabwe             148            3.145  0.45700  0.64900
# 1089  Afghanistan             149            2.523  0.37000  0.00000
#
#       Life Expectancy  Freedom  Corruption  Generosity  Education Expenditure  \
# ...

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1090 entries, 0 to 1089
# Data columns (total 24 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country                               1090 non-null   object
#  1   Happiness Rank                        1090 non-null   int64
#  2   Happiness Score                       1090 non-null   float64
#  3   GDP                                   1090 non-null   float64
#  4   Family                                1090 non-null   float64
#  5   Life Expectancy                       1090 non-null   float64
#  6   Freedom                               1090 non-null   float64
#  7   Corruption                            1089 non-null   float64
#  8   Generosity                            1090 non-null   float64
#  9   Education Expenditure                 564 non-null    float64
# ...

# %%
all_df = all_df.astype({'Migrating into the country(combined)':'float',
    'Migrating into the country(males)':'float',
    'Migrating into the country(females)':'float',
    'Migrating from the country(combined)':'float',
    'Migrating from the country(males)':'float',
    'Migrating from the country(females)':'float',})

# %%
all_df = all_df[["Country","Code","Year" ,"Happiness Rank","Happiness Score",
                "GDP","Family","Life Expectancy",
                "Freedom","Corruption","Generosity","Education Expenditure",
                "Age 65+","Age 64-25","Age 24-15","Age 14-5","Age <5","Total Population",
                "Migrating into the country(combined)","Migrating into the country(males)","Migrating into the country(females)",
                "Migrating from the country(combined)","Migrating from the country(males)","Migrating from the country(females)"]]

# %%
all_df = all_df[all_df['Code'].notna()]

# %%
#read naming data to match based data
all_df["Country"] = all_df["Country"].replace({"\"Hong Kong S.A.R., China\"": "Hong Kong",
    "Hong Kong S.A.R. of China":"Hong Kong"})

# %%
# Convert DataFrame to JSON 
json_data = all_df.to_json(orient='records')

# %%
# Write JSON output to a JavaScript file
with open('../Clean Data/data.js', 'w') as f:
    f.write('var data = ')
    f.write(json_data)
    f.write(';')

# %%
# Write JSON output to a JavaScript file
with open('../../Static/data.js', 'w') as f:
    f.write('var data = ')
    f.write(json_data)
    f.write(';')

# %%
# Export file as a CSV, without the Pandas index, but with the header
all_df.to_csv("../Clean Data/cleaned_data.csv", index=False, header=True)
